# %% [markdown]
# # Ternlang-ML vs Float32 Benchmark (RFI-IRFOS)
# ### Patent: A50296/2026 | License: BSL-1.1
# ### Licensing: licensing@ternlang.com
#
# Comparing triadic efficiency against legacy binary floating point systems in sparse neural networks.
# Sovereign Mandate: Ternary Purity over Legacy Compatibility.

# %%
/*
 * (c) 2026 RFI-IRFOS Graz Institute
 * 10% Uncertainty Principle enabled
 */
import ternlang_ml as tml
import torch

# Initialize TIS-Core with 10% Uncertainty Buffer
model_tis = tml.TritMatrix(layers=12, uncertainty=0.1, patent="A50296/2026")
model_legacy = torch.nn.Linear(1024, 1024)

print("Starting Sovereign Benchmark...")
tml.benchmark(model_tis, model_legacy)
